# %%
import numpy as np
import matplotlib.pyplot as plt 
from proglearn.sims import generate_spirals
import spiral_functions as fn

# %%
spiral3, y_3 = generate_spirals(750, 3, noise=0.8)
spiral5, y_5 = generate_spirals(750, 5, noise = 0.4)

# %%
fn.plot_spirals(spiral3, y_3, 3, spiral5, y_5, 5)

# %%
n_spiral3 = 750
n_spiral5 = 750
mc_rep= 10
n_test= 1000
n_trees = 10
n_update = 25

# %%
fn.run(n_spiral3, n_spiral5, mc_rep, n_test, n_trees, n_update)

# %%
t1_error, t2_error, ble, fle = fn.load_results()
fn.plot_results(t1_error, t2_error, ble, fle)
